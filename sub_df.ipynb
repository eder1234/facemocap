# %%
import open3d as o3d
import numpy as np
import pandas as pd
#import functions as f
import matplotlib.pyplot as plt
#from scipy.interpolate import interp1d
import seqpc
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
facemocap_df = pd.read_pickle('facemocap_df.pkl')
facemocap_df.sample(10)
# Out:
#                 File name                                       Original SPC
# 3                M5_3.csv  [[172.556198, 153.536407, 1086.332031, 144.728...  \
# 377  P01_D01_M3x10_e6.csv  [[263.616, 285.31, 553.101, 267.948, 273.082, ...
# 197           RL01_M4.csv  [[278.092, -122.249, 1099.64, 278.834, -134.90...
# 239    P22_D1_M2x10e8.csv  [[16.4007, 160.04, 644.917, 15.5284, 153.84, 6...
# 582    P23_D1_M5x10e9.csv  [[14.9692, 195.88, 571.758, 86.8453, 179.671, ...
# 295  P19_D01_M5x10_e6.csv  [[320.107, 275.332, 655.763, 316.53, 271.663, ...
# 35               M4_4.csv  [[269.876, -110.899, 1166.4, 244.523, -115.832...
# 158      P18_D1_M1_e4.csv  [[141.223, 202.815, 642.184, 141.195, 195.468,...
# 279           AC_M4x3.csv  [[105.754, 416.926, 612.852, 92.4419, 413.737,...
# 238  P19_D01_M3x10_e7.csv  [[343.537, 279.879, 655.215, 339.813, 275.617,...
#
#      Name  Experimentator MoCap platform     Pathology  Repetitive Movement
# ...

# %%
# Create a dataframe that only contains col 'Pathology'=False
healthy_df = facemocap_df[facemocap_df["Pathology"] == False]
# Only preserve File name, Original SPC and Movement cols
healthy_df.head()
# Out:
#       File name                                       Original SPC  Name
# 0  MP01_M05.csv  [[82.0149, 336.328, 1414.31, 80.2184, 347.124,...  MP01  \
# 1  MP01_M04.csv  [[80.96, 334.745, 1412.78, 79.7897, 345.616, 1...  MP01
# 2  MP01_M02.csv  [[81.5083, 338.102, 1415.29, 80.0191, 349.103,...  MP01
# 3  MP01_M01.csv  [[77.6899, 336.869, 1408.5, 77.865, 347.594, 1...  MP01
# 4  MP01_M03.csv  [[81.3165, 337.815, 1412.57, 80.4275, 348.679,...  MP01
#
#    Experimentator MoCap platform Pathology  Repetitive Movement        Date
# 0  François-Régis            UTC     False       False        5  12-05-2015
# 1  François-Régis            UTC     False       False        4  12-05-2015
# 2  François-Régis            UTC     False       False        2  12-05-2015
# 3  François-Régis            UTC     False       False        1  12-05-2015
# 4  François-Régis            UTC     False       False        3  12-05-2015
